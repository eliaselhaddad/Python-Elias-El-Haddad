# %%
import numpy as np
import matplotlib.pyplot as plt

with open("datapoints.txt", "r") as f_read:
    file = f_read.readlines()

    file.pop(0) # removes the first line 

    data = []
    for i in file:
        data.append(i.strip()) # removes \n

    for i, element in enumerate(data, 1):
        print(f"{i}. {element}")

    for i in data:
        if i 

    # converts one-dimensional list into a two-dimensional list
    # separating every data set on its own
    # data_2d = np.reshape(data_1d, (150, 1))  
    # print(f"{len(data_2d) = }")
    # print(data_2d.sort())
    # print(repr(data_2d))
    # data_2d[1][1]
    # for i, element in enumerate(data_2d, 1):
    #     print(f"{i}. {element}")
# Out:
# 1. 21.959384499160468, 31.23956701424158, 0
# 2. 23.63591632187622, 36.46821490673444, 1
# 3. 17.714056417303343, 31.44170391314962, 0
# 4. 21.78020031891186, 33.213397759738264, 1
# 5. 25.20630552859312, 36.558816149350534, 1
# 6. 19.332572350434354, 32.25325633655492, 0
# 7. 24.73645685241186, 35.33291181124776, 1
# 8. 23.79257560586339, 38.10372825362463, 1
# 9. 24.557612968127465, 36.73144402805611, 1
# 10. 20.191281253428173, 35.06966921830237, 0
# 11. 25.813562951888365, 35.561029988644336, 1
# 12. 24.923378667802954, 34.463907946680294, 1
# 13. 25.311244044578427, 34.117212558131975, 1
# 14. 22.819091361866796, 34.25516433025548, 1
# 15. 19.639358214988224, 34.56117030001663, 0
# 16. 18.341233265627693, 31.399261188293124, 0
# 17. 22.723629043769336, 34.83845262048311, 1
# 18. 25.82936770950206, 33.16210202637511, 1
# 19. 20.23890182459327, 32.78945132868386, 0
# 20. 17.905128921789093, 28.88813385482529, 0
# 21. 24.385289647525166, 37.335669057387726, 1
# ...
